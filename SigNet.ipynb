# %% [markdown]
# # <u>Detecting Signature Similarity using Tensorflow 2 (By Aadit Kapoor).</u>
# <p>
#     My Grandfather was an handwriting expert. His work consisted of anazlying/verifying forged and real signatures. While I agree that we cannot replace that job with an A.I with a 100% accuracy, we certanily build a system capable of aiding human beings.
# </p>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import accuracy_score
import seaborn as sns
from shutil import copy
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from skimage.metrics import structural_similarity
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import random
import os

np.random.seed(42)

DATA_DIR = "./Dataset_Signature_Final/Dataset"

# %% [markdown]
# # <u>The Dataset</u>
# - We will be using the handwritten signatures dataset from Kaggle. (https://www.kaggle.com/divyanshrai/handwritten-signatures)
# - Like any project, we will first start by exploring and loading the data.

# %%
def load_data(DATA_DIR=DATA_DIR, test_size=0.2, verbose=True, load_grayscale=True):
    """
        Loads the data into a dataframe.
        
        Arguments:
            DATA_DIR: str
            test_size: float
        Returns:
            (x_train, y_train,x_test, y_test, x_val, y_val, df)
    """
    features = []
    features_forged = []
    features_real = []
    features_dict = {}
    labels = [] # forged: 0 and real: 1
    mode = "rgb"
    if load_grayscale:
        mode = "grayscale"
    
    for folder in os.listdir(DATA_DIR):
        # forged images
        if folder == '.DS_Store' or folder == '.ipynb_checkpoints':
            continue
        print ("Searching folder {}".format(folder))
        for sub in os.listdir(DATA_DIR+"/"+folder+"/forge"):
            f = DATA_DIR+"/"+folder+"/forge/" + sub
            img = load_img(f,color_mode=mode, target_size=(150,150))
            features.append(img_to_array(img))
            features_dict[sub] = (img, 0)
            features_forged.append(img)
            if verbose:
                print ("Adding {} with label 0".format(f))
            labels.append(0) # forged
        # real images
        for sub in os.listdir(DATA_DIR+"/"+folder+"/real"):
            f = DATA_DIR+"/"+folder+"/real/" + sub
            img = load_img(f,color_mode=mode, target_size=(150,150))
            features.append(img_to_array(img))
            features_dict[sub] = (img, 1)
            features_real.append(img)
            if verbose:
                print ("Adding {} with label 1".format(f))
            labels.append(1) # real
            
    features = np.array(features)
    labels = np.array(labels)
    
    x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)
    
    print ("Generated data.")
    return features, labels,features_forged, features_real,features_dict,x_train, x_test, y_train, y_test, x_val, y_val


def convert_label_to_text(label=0):
    """
        Convert label into text
        
        Arguments:
            label: int
        Returns:
            str: The mapping
    """
    return "Forged" if label == 0 else "Real"

# %%
features, labels,features_forged, features_real, features_dict,x_train, x_test, y_train, y_test, x_val, y_val = load_data(verbose=True, load_grayscale=False)
# Out:
# Searching folder dataset1
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100001.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100002.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100003.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100004.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100005.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100006.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100007.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100008.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100009.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100010.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100011.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02100012.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101001.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101002.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101003.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101004.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101005.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101006.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101007.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101008.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101009.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101010.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101011.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/dataset1/forge/02101012.png with label 0
# Adding ./Dataset_Signature_Final/Dataset/data
png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/04404044.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/04405044.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/04601046.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/04602046.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/04603046.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/04604046.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/04605046.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/06301063.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/06302063.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/06303063.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/06304063.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/06305063.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07001070.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07002070.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07003070.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07004070.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07005070.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07101071.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07102071.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07103071.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07104071.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07105071.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07701077.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07702077.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07703077.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07704077.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/07705077.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08401084.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08402084.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08403084.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08404084.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08405084.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08501085.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08502085.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08503085.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08504085.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08505085.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08601086.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08602086.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08603086.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08604086.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08605086.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08901089.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08902089.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08903089.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08904089.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/08905089.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09201092.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09202092.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09203092.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09204092.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09205092.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09301093.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09302093.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09303093.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09304093.png with label 1
# Adding ./Dataset_Signature_Final/Dataset/dataset4/real/09305093.png with label 1
# Generated data.

# %%
print(features)
# Out:
# [[[[204. 204. 204.]
#    [204. 204. 204.]
#    [204. 204. 204.]
#    ...
#    [195. 195. 195.]
#    [195. 195. 195.]
#    [194. 194. 194.]]
#
#   [[204. 204. 204.]
#    [204. 204. 204.]
#    [203. 203. 203.]
#    ...
#    [194. 194. 194.]
#    [194. 194. 194.]
#    [193. 193. 193.]]
#
#   [[201. 201. 201.]
#    [201. 201. 201.]
#    [204. 204. 204.]
#    ...
#    [192. 192. 192.]
#    [197. 197. 197.]
#    [192. 192. 192.]]
#
#   ...
#
#   [[190. 190. 190.]
#    [192. 192. 192.]
#    [191. 191. 191.]
#    ...
#    [173. 173. 173.]
#    [181. 181. 181.]
#    [182. 182. 182.]]
#
#   [[189. 189. 189.]
#    [190. 190. 190.]
#    [190. 190. 190.]
#    ...
#    [168. 168. 168.]
#    [183. 183. 183.]
#    [185. 185. 185.]]
#
#   [[190. 190. 190.]
#    [191. 191. 191.]
#    [191. 191. 191.]
#    ...
#    [175. 175. 175.]
#    [180. 180. 180.]
#    [176. 176. 176.]]]
#
#
#  [[[242. 252. 253.]
#    [240. 251. 253.]
#    [243. 252. 253.]
#    ...
#    [238. 250. 253.]
#    [240. 251. 253.]
#    [242. 252. 252.]]
#
#   [[241. 252. 253.]
#    [240. 251. 253.]
#    [243. 252. 253.]
#    ...
#    [239. 250. 253.]
#    [239. 251. 253.]
#    [242. 252. 253.]]
#
#   [[241. 252. 253.]
#    [240. 251. 253.]
#    [243. 252. 253.]
#    ...
#    [239. 250. 253.]
#    [239. 251. 253.]
#    [242. 252. 253.]]
#
#   ...
#
#   [[243. 252. 252.]
#    [243. 252. 252.]
#    [242. 252. 253.]
#    ...
#    [241. 252. 253.]
#    [240. 251. 253.]
#    [242. 252. 253.]]
#
#   [[243. 252. 252.]
#    [243. 252. 252.]
#    [242. 252. 253.]
#    ...
#    [241. 252. 253.]
#    [240. 251. 253.]
#    [242. 252. 253.]]
#
#   [[244. 252. 252.]
#    [243. 252. 252.]
#    [243. 252. 253.]
#    ...
#    [238. 249. 254.]
#    [239. 250. 253.]
#    [242. 252. 253.]]]
#
#
#  [[[241. 251. 253.]
#    [242. 252. 253.]
#    [243. 252. 252.]
#    ...
#    [242. 252. 253.]
#    [242. 252. 253.]
#    [240. 252. 253.]]
#
#   [[241. 251. 253.]
#    [242. 252. 253.]
#    [243. 252. 252.]
#    ...
#    [242. 252. 253.]
#    [242. 252. 253.]
#    [240. 252. 253.]]
#
#   [[240. 250. 253.]
#    [243. 252. 252.]
#    [241. 251. 253.]
#    ...
#    [243. 252. 252.]
#    [239. 251. 253.]
#    [242. 252. 253.]]
#
#   ...
#
#   [[243. 252. 252.]
#    [243. 252. 252.]
#    [243. 252. 253.]
#    ...
#    [243. 252. 253.]
#    [241. 252. 253.]
#    [241. 252. 253.]]
#
#   [[242. 252. 252.]
#    [243. 252. 253.]
#    [242. 252. 253.]
#    ...
#    [242. 252. 253.]
#    [242. 252. 253.]
#    [242. 252. 252.]]
#
#   [[242. 252. 252.]
#    [243. 252. 253.]
#    [242. 252. 253.]
#    ...
#    [242. 252. 253.]
#    [242. 252. 253.]
#    [242. 252. 252.]]]
#
#
#  ...
#
#
#  [[[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   ...
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]]
#
#
#  [[[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   ...
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]]
#
#
#  [[[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   ...
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]]]

# %% [markdown]
# - We extract all the data in the respective variables where 0 label stands for forged and 1 stands for real.
# - The images are loaded with as channels as 1 (grayscale)

# %% [markdown]
# # <u>Visualization of the data</u>
# - Let us get a closer look at the data.

# %%
f, axarr = plt.subplots(3,3)
axarr[0,0].imshow(features[0]/255.)
axarr[0,0].text(2, 2, labels[0], bbox={'facecolor': 'white', 'pad': 3})
axarr[0,1].imshow(features[1]/255.)
axarr[0,1].text(2, 2, labels[1], bbox={'facecolor': 'white', 'pad': 3})
axarr[0,2].imshow(features[2]/255.)
axarr[0,2].text(2, 2, labels[2], bbox={'facecolor': 'white', 'pad': 3})
axarr[1,0].imshow(features[300]/255.)
axarr[1,0].text(2, 2, labels[300], bbox={'facecolor': 'white', 'pad': 3})
axarr[1,1].imshow(features[400]/255.)
axarr[1,1].text(2, 2, labels[400], bbox={'facecolor': 'white', 'pad': 3})
axarr[1,2].imshow(features[512]/255.)
axarr[1,2].text(2, 2, labels[512], bbox={'facecolor': 'white', 'pad': 3})
axarr[2,0].imshow(features[6]/255.)
axarr[2,0].text(2, 2, labels[6], bbox={'facecolor': 'white', 'pad': 3})
axarr[2,1].imshow(features[200]/255.)
axarr[2,1].text(2, 2, labels[200], bbox={'facecolor': 'white', 'pad': 3})
axarr[2,2].imshow(features[100]/255.)
axarr[2,2].text(2, 2, labels[100], bbox={'facecolor': 'white', 'pad': 3})

print ("Distribution: {}".format(np.bincount(labels)))
# Out:
# Distribution: [360 360]

# %% [markdown]
# - Here we show some snapshots of the signatures.
# - The distribution of the data is uniform as we have 360 as forged and 360 images as real.
# - 0 represents forged and 1 represents real
# - The images are loaded with a target_size of (150,150)

# %% [markdown]
# # <u>Approach #1: Similarity in images (signatures) using MSE and SSIM.</u>
# <p>
#     To compute similarity between images we can either use <b>MSE (Mean Squared Error) or SSIM(Structural similarity)</b>. As you can see the formulas are pretty straightforward and fortunately scikit-learn provides an implmenetation for SSIM.
# </p>

# %% [markdown]
# ![image.png](attachment:d68e5415-829a-4f75-95ab-3ff0b2cd2411.png)

# %%
def mse(A, B):
    """
        Computes Mean Squared Error between two images. (A and B)
        
        Arguments:
            A: numpy array
            B: numpy array
        Returns:
            err: float
    """
    
    # sigma(1, n-1)(a-b)^2)
    err = np.sum((A - B) ** 2)
    
    # mean of the sum (r,c) => total elements: r*c
    err /= float(A.shape[0] * B.shape[1])
    
    return err


def ssim(A, B):
    """
        Computes SSIM between two images.
        
        Arguments:
            A: numpy array
            B: numpy array
            
        Returns:
            score: float
    """
    
    return structural_similarity(A, B)

# %% [markdown]
# ### Here we take two images from the same person, one of them is real and the other is a fake.
# - We will try to compute the similarity between these two images.

# %%
A = features_dict["02100002.png"] # 2 by 21 person
B = features_dict["00200002.png"] # 2 by 2 [real]

# %%
print ("Signature: {}".format(convert_label_to_text(A[1])))
plt.imshow(A[0])
# Out:
# Signature: Forged

# %%
print ("Signature: {}".format(convert_label_to_text(B[1])))
plt.imshow(B[0])
# Out:
# Signature: Real

# %%
A_array = img_to_array(A[0])
B_array = img_to_array(B[0])
print ("MSE Error: {}".format(mse(A_array, B_array)))
print("SSIM: {}".format(ssim(A_array.flatten(),B_array.flatten())))
# Out:
# MSE Error: 2780.9489777777776
# SSIM: 0.8162866467749774

# %% [markdown]
# - As you can see, MSE Error does not have a fixed bound whereas SSIM has a fixed bound between -1 and 1.
# - Lower MSE represents Similar images whereas lower SSIM represents Similar images.

# %% [markdown]
# # <u>Approach #2: Building a classifier using CNNs that can detect forged or real signatures.</u>
# <p>
#     With this approach, we will try to come up with a classifier (using CNNs) to detect forged or real signatures.<br>
#     As CNNs are known to detect intricate features among images, we will experiment with a this classifier.
# </p>

# %% [markdown]
# - We are bound to encounter with overfitting as we do not have enough data.
# - We will probably use Image Augementation to generate more training data.

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64, (3,3), input_shape=(150,150,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(2))
model.add(tf.keras.layers.Conv2D(32, (3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(2))
model.add(tf.keras.layers.Conv2D(16, (3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(2))
model.add(tf.keras.layers.Conv2D(16, (3,3), activation='relu'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss=tf.keras.losses.binary_crossentropy, metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 16)        2320
# _________________________________________________________________
# flatten (Flatten)            (None, 3600)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1843712
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,871,425
# Trainable params: 1,871,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
# normalize inputs
x_train /= 255.
x_val /= 255.
x_test /= 255.

# %%
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_val, y_val))
# Out:
# Epoch 1/5
# 14/14 [==============================] - 14s 988ms/step - loss: 0.7634 - acc: 0.4977 - val_loss: 0.6882 - val_acc: 0.5556
# Epoch 2/5
# 14/14 [==============================] - 13s 908ms/step - loss: 0.6968 - acc: 0.4792 - val_loss: 0.6947 - val_acc: 0.4444
# Epoch 3/5
# 14/14 [==============================] - 13s 899ms/step - loss: 0.6913 - acc: 0.5208 - val_loss: 0.6972 - val_acc: 0.4444
# Epoch 4/5
# 14/14 [==============================] - 12s 879ms/step - loss: 0.6838 - acc: 0.5556 - val_loss: 0.7037 - val_acc: 0.4653
# Epoch 5/5
# 14/14 [==============================] - 12s 887ms/step - loss: 0.6652 - acc: 0.6065 - val_loss: 0.6886 - val_acc: 0.4931

# %%
def plot_history(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

plot_history(history)

# %% [markdown]
# - Model is clearly overfitting (one probable reason is the lack of training data.)
# - On increasing the epochs, the model is clearly overfitting

# %% [markdown]
# ## <u>Transfer Learning using Inception.</u>

# %%
# loading Inception
model2 = tf.keras.applications.InceptionV3(include_top=False, input_shape=(150,150,3))

# %%
# freezing layers
for layer in model2.layers:
    layer.trainable=False

# %%
# getting mixed7 layer
l = model2.get_layer("mixed7")

# %%
print ("mixed7 shape: {}".format(l.output_shape))
# Out:
# mixed7 shape: (None, 7, 7, 768)

# %%
x = tf.keras.layers.Flatten()(l.output)
x = tf.keras.layers.Dense(1024, activation='relu')(x)
x = tf.keras.layers.Dropout(.5)(x)                  
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)           
net = tf.keras.Model(model2.input, x)

# %%
net.compile(optimizer='adam', loss=tf.keras.losses.binary_crossentropy, metrics=['acc'])

# %%
h2 = net.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=5)
# Out:
# Epoch 1/5
# 14/14 [==============================] - 15s 1s/step - loss: 2.9192 - acc: 0.5741 - val_loss: 1.5618 - val_acc: 0.5556
# Epoch 2/5
# 14/14 [==============================] - 14s 983ms/step - loss: 0.6454 - acc: 0.7940 - val_loss: 0.3676 - val_acc: 0.8681
# Epoch 3/5
# 14/14 [==============================] - 14s 980ms/step - loss: 0.3033 - acc: 0.8935 - val_loss: 0.2463 - val_acc: 0.9028
# Epoch 4/5
# 14/14 [==============================] - 14s 985ms/step - loss: 0.0966 - acc: 0.9537 - val_loss: 0.1824 - val_acc: 0.9236
# Epoch 5/5
# 14/14 [==============================] - 14s 969ms/step - loss: 0.0698 - acc: 0.9769 - val_loss: 0.2441 - val_acc: 0.8889

# %%
plot_history(h2)

# %% [markdown]
# - Clearly the model overfits after 3 epochs.
# - But the result is still better than the previous one.

# %%
preds = net.predict(x_test)
pred_labels = []

# %%
# threshold is 0.5
for p in preds:
    if p >= 0.5:
        pred_labels.append(1)
    else:
        pred_labels.append(0)
pred_labels = np.array(pred_labels)

# %%
print ("Accuracy on test set: {}".format(accuracy_score(y_test, pred_labels)))
# Out:
# Accuracy on test set: 0.9097222222222222

# %% [markdown]
# <p>
#     These two approaches show that if we use transfer learning, we get much better results than using a plain CNN model.
#     Keep in mind, these approaches do not learn the similarity function but these focus on the classifying whether the image in forged or real. There are still many ways we can improve our model, one is by augmenting data.
# </p>
#
# ### With our third approach, we will try to learn the similarity function. We will use something called Siamese networks (due to nature of our data i.e less number of training examples)

# %% [markdown]
# # <u>Approach #3: Siamese networks for image similarity</u>
# <p>
#     In this approach, we will use Siamese networks to learn the similarity function. Siamese means 'twins' and the biggest difference between normal nn's is that these networks try to learn the approximate the similarity function instead of trying to classify.
#     <hr><strong>Refer: https://arxiv.org/pdf/1709.08761.pdf</strong>
#     </p>

# %% [markdown]
# - We first create a common feature vector for our images. We will pass two images (positive and negative) and use a contrastive loss function (Distance metric (l1 distance)) and in the end we squash the output between 1 and 0 (sigmoid) to get the final result.
# ![image.png](attachment:1f544865-466e-4696-af69-2a3dd5e820b9.png)

# %%
# the NN is the diagram
feature_vector = tf.keras.Sequential()
feature_vector.add(tf.keras.layers.Conv2D(64,3, activation='relu', input_shape=(150,150,3)))
feature_vector.add(tf.keras.layers.BatchNormalization())
feature_vector.add(tf.keras.layers.Conv2D(32,3, activation='relu'))
feature_vector.add(tf.keras.layers.BatchNormalization())
feature_vector.add(tf.keras.layers.Conv2D(16, 3,activation='relu'))
feature_vector.add(tf.keras.layers.MaxPool2D((2,2)))
feature_vector.add(tf.keras.layers.Flatten())
feature_vector.add(tf.keras.layers.Dropout(0.2))
feature_vector.add(tf.keras.layers.Dense(512, activation='relu'))

# %%
feature_vector.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 64)      1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 148, 148, 64)      256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 146, 146, 32)      18464
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 146, 146, 32)      128
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 144, 144, 16)      4624
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 72, 72, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 82944)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 82944)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               42467840
# =================================================================
# Total params: 42,493,104
# Trainable params: 42,492,912
# Non-trainable params: 192
# _________________________________________________________________

# %%
# creating the siamese network
im_a = tf.keras.layers.Input(shape=(150,150,3))
im_b = tf.keras.layers.Input(shape=(150,150,3))

encoded_a = feature_vector(im_a)
encoded_b = feature_vector(im_b)

combined = tf.keras.layers.concatenate([encoded_a, encoded_b])
combine = tf.keras.layers.BatchNormalization()(combined)
combined = tf.keras.layers.Dense(4, activation = 'linear')(combined)
combined = tf.keras.layers.BatchNormalization()(combined)
combined = tf.keras.layers.Activation('relu')(combined)
combined = tf.keras.layers.Dense(1, activation = 'sigmoid')(combined)

sm = tf.keras.Model(inputs=[im_a, im_b], outputs=[combined])
sm.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 512)          42493104    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1024)         0           sequential[0][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            4100        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4)            16          dense_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4)            0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            5           activation[0][0]
# ==================================================================================================
# Total params: 42,497,225
# Trainable params: 42,497,025
# Non-trainable params: 200
# __________________________________________________________________________________________________

# %%
sm.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['mae'])

# %% [markdown]
# # <u>Dataset Generation</u>
# <p>
#     To generate the required dataset, we will try two approaches. First we will generate data on the basis of labels. If two images have the same label (1 or 0), then they are similar. We will generate data in pairs in the form (im_a, im_b, label).<br>
#     Second we will generate data on the basis of person number. According to the dataset, 02104021.png represents the signature produced by person 21 (i.e real).
# </p>

# %% [markdown]
# ## Data generation Approach #1:
# <p>
#     Here we are assuming similarity on the basis of labels. If two images have the same label (i.e 1 or 0) then they are similar.
# </p>

# %%
def generate_data_first_approach(features, labels, test_size=0.25):
    """
        Generate data in pairs according to labels.
        Arguments:
            features: numpy
            labels: numpy
    """
    im_a = [] # images a
    im_b = [] # images b
    pair_labels = []
    for i in range(0, len(features)-1):
        j = i + 1
        if labels[i] == labels[j]:
            im_a.append(features[i])
            im_b.append(features[j])
            pair_labels.append(1) # similar
        else:
            im_a.append(features[i])
            im_b.append(features[j])
            pair_labels.append(0) # not similar
            
    pairs = np.stack([im_a, im_b], axis=1)
    pair_labels = np.array(pair_labels)
    x_train, x_test, y_train, y_test = train_test_split(pairs, pair_labels, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)
    return x_train, y_train, x_test, y_test, x_val, y_val, pairs, pair_labels

# %%
x_train, y_train, x_test, y_test, x_val, y_val, pairs, pair_labels = generate_data_first_approach(features, labels)

# %%
plt.imshow(pairs[:,0][0]/255.)
plt.show()
plt.imshow(pairs[:,1][0]/255.)
plt.show()
print("Label: ",pair_labels[0])
# Out:
# Label:  1

# %%
# x_train[:,0] => axis=1 (all 150,150,3) x_train[:,1] => axis=1 (second column)
sm.fit([x_train[:,0], x_train[:,1]], y_train, validation_data=([x_val[:,0],x_val[:,1]], y_val),epochs=1)
# Out:
# 13/13 [==============================] - 80s 6s/step - loss: 0.3151 - mae: 0.2573 - val_loss: 1.1236e-04 - val_mae: 1.1237e-04

# %% [markdown]
# - The metric is calculating the L1-Distance (MAE) between the y_hat and y.
# - Due to computation limitations,we only train it for one epoch
# - This represents a very simple siamese network capable of learning the similarity function.

# %% [markdown]
# ## Data Generation Approach #2
# <p>
#     In this approach, we try to setup a dataset where we cross multiply each signature with other number signature.<br>
#     <strong> The inputs and the outputs must be the same size.</strong>
# </p>

# %%
def generate_data(person_number="001"):
    x = list(features_dict.keys())
    im_r = []
    im_f = []
    labels = [] # represents 1 if signature is real else 0
    for i in x:
        if i.startswith(person_number):
            if i.endswith("{}.png".format(person_number)):
                im_r.append(i)
                labels.append(1)
            else:
                im_f.append(i)
                labels.append(0)
    return im_r, im_f, labels


def generate_dataset_approach_two(size=100, test_size=0.25):
    """
        Generate data using the second approach.
        Remember input and output must be the same size!
        
        Arguments:
            features: numpy array
            labels: numpy array
            size: the target size (length of the array)
        Returns:
            x_train, y_train
    """
    im_r = []
    im_f = []
    ls = []

    ids = ["001","002","003",'004','005','006','007','008','009','010','011','012','013','014','015','016','017','018','019','020','021','022',
           '023','024','025','026','027','028','029','030']
    
    for i in ids:
        imr, imf, labels = generate_data(i)
        
        # similar batch
        for i in imr:
            for j in imr:
                im_r.append(img_to_array(features_dict[i][0]))
                im_f.append(img_to_array(features_dict[j][0]))
                ls.append(1) # they are similar
        
        # not similar batch
        for k in imf:
            for l in imf:
                im_r.append(img_to_array(features_dict[k][0]))
                im_f.append(img_to_array(features_dict[l][0]))
                ls.append(0) # they are not similar
    
    print(len(im_r), len(im_f))
    pairs = np.stack([im_r, im_f], axis=1)
    ls = np.array(ls)
    
    x_train, x_test, y_train, y_test = train_test_split(pairs, ls, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)
    return x_train, y_train, x_test, y_test, x_val, y_val, pairs, ls

# %%
x_train, y_train, x_test, y_test, x_val, y_val, pairs, ls = generate_dataset_approach_two()
# Out:
# 10781 10781

# %% [markdown]
# - Now we have the dataset generated. We will train the network.

# %%
sm.fit([x_train[:,0], x_train[:,1]], y_train, epochs=1, validation_data=([x_test[:,0], x_test[:,1]], y_test))

# %%
plt.imshow(x_train[:,0][0]/255.)
plt.show()
plt.imshow(x_train[:,0][1]/255.)
print("Label: ",y_train[0])
# Out:
# Label:  0
